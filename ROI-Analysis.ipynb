# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Data Preparation

# %%
# Read the CSV
df = pd.read_csv('data/movies.csv')

cleaned_income = df[(df['Income'] != 'Unknown') &
                    (df['Income'].str.contains('\$', na=False))
                    ]
# Out:
# 2000
# 1855
